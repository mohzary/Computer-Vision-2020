# %%
#To import all required packages for HW2
from glob import glob
import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
import imutils
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from fishervector import FisherVectorGMM
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics import silhouette_samples, silhouette_score

import seaborn as sns
# %matplotlib inline

# %%
#Step(1) to extract images from dataset


# images list to store extracted images from data set folder
images = [] 
# To initilzie the number of images we want to use 
numberOfImages = 200

#getImages() function to extract images from local folder 
def getImages(size):
    
    
    #To loop through images in the dataset folder
    for image in glob("dataset/*.jpg"):
        if (len(images)<size):
            #To read imag from dataset folder using cv2, cv2 reads images in BGR format
            imgBGR = cv2.imread(image)
            #To convert image into gray scale
            grayImage = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2GRAY)
            #To save image in the images list to be used later by another functions
            images.append(grayImage)
    #To show the number of extracted images    
    print (len(images), " Images were extracted from dataset.")
    
    
    
#To call getImages() function   
getImages(numberOfImages)
# Out:
# 200  Images were extracted from dataset.

# %%
#Question(1)
#Step(2): To build a function that computes HoG, Dense SIFT, and Sift.


#Three methods we are going to use to compute image features
methods = ["SIFT", "Dense", "HoG"]


#python function that computes n x d features by calling  HoG, DSIFT and SIFT functions
def computeImageFeatures(image, method):
    
    #To compute HoG:
    if method == "HoG":
        hog = cv2.HOGDescriptor((128, 64), (16, 16), (8, 8), (8, 8), 9)
        h = hog.compute(image, None)
                
        return h
    
    #To compute Dense:    
    elif method == "Dense":
        sift = cv2.xfeatures2d.SIFT_create()
        step_size = 5
        keyPoints = [cv2.KeyPoint(x, y, step_size) for y in range(0, image.shape[0], step_size) 
                                    for x in range(0, image.shape[1], step_size)]
        keyPoints, descriptors = sift.compute(image, keyPoints)
        
                
        return descriptors
    
    
    #To compute SIFT
    elif method =="SIFT":
        sift = cv2.xfeatures2d.SIFT_create()
        keyPoints, descriptors = sift.detectAndCompute(image, None)
        
          
        return descriptors
    

#To call computeImageFeatures and store features in three different lists
for method in methods:
    for image in images:
        if method == "HoG":
            
            #An array to store computed image features using HoG
            imageFeatures_HoG = (computeImageFeatures(image, method))
            
        elif method == "Dense":
            
            #An array to store computed image features using Dense SIFT
            imageFeatures_Dense=(computeImageFeatures(image, method))
            
        elif method =="SIFT":
            
            #An array to store computed image features using SIFT
            imageFeatures_SIFT = (computeImageFeatures(image, method))
            
            
print(len(imageFeatures_HoG))
print(len(imageFeatures_Dense))
print(len(imageFeatures_SIFT))
# Out:
# 13022100
# 12288
# 1244

# %%
#Question(2)
#Step(3): To build a function that computes Fisher Vector models of image features


#Number of GMM components
k = 64

#python function that computes fisher vector model
def getFisherVectorModel(features, k, method):
    
    kd = k * 48

    features = np.array(features)
    features = np.vstack(features)

    features_indices = np.random.choice(features.shape[0], kd)
    features = features[features_indices]
    features = features.astype(np.float32)
    
    # compute mean and covariance matrix for the PCA 
    mean = features.mean(axis = 0)
    
    features = features - mean

    covariance = np.dot(features.T, features)

    #print("covariance = ", covariance )        
    #print(" features", features) 
    
    # To compute PCA  and keep only 64 dimensions
    eig_values, eig_vecs = np.linalg.eig(covariance)
    
    
    # To sort eig_values by increasing value
    perm = eig_values.argsort() 

    PCA = eig_vecs[:, perm[64:128]]
 
    
    features = np.matmul(features, PCA)
            
    print("final features = ", features.shape)     
    
    
    #To train GMM model on the extracted features and return gmm:
    gmm = GaussianMixture(n_components=k).fit(features)
    return gmm, features



#To call getFisherVectorModel and store features in three different lists
for method in methods:
    if method == "SIFT":
        
        #An array to store computed fv_GMM using SIFT features
        fv_GMM_SIFT , sift_f= (getFisherVectorModel(imageFeatures_SIFT, k, method))

    elif method == "Dense":
        
        #An array to store computed fv_GMM using Dense SIFT featurs
        fv_GMM_Dense, dense_f = (getFisherVectorModel(imageFeatures_Dense, k, method))
        
    

print("FV SIFT GMM: ", fv_GMM_SIFT)
print("FV Dense GMM: ", fv_GMM_Dense)
# Out:
# final features =  (3072, 64)
# final features =  (3072, 64)
# FV SIFT GMM:  GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=64, n_init=1,
#                 precisions_init=None, random_state=None, reg_covar=1e-06,
#                 tol=0.001, verbose=0, verbose_interval=10, warm_start=False,
#                 weights_init=None)
# FV Dense GMM:  GaussianMixture(covariance_type='full', init_params='kmeans', max_iter=100,
#                 means_init=None, n_components=64, n_init=1,
#                 precisions_init=None, random_state=None, reg_covar=1e-06,
#                 tol=0.001, verbose=0, verbose_interval=10, warm_start=False,
#                 weights_init=None)

# %%
#Question(2)
#To build a function that computes VLAD Vector models of image features


#Number of clusters 
k = 64

#python function that computes VLAD vector model
def getVLADVectorModel(features, k, method):
    
    kd = k * 48

    features = np.array(features)
    features = np.vstack(features)

    features_indices = np.random.choice(features.shape[0], kd)
    features = features[features_indices]
    features = features.astype(np.float32)
    
    # compute mean and covariance matrix for the PCA 
    mean = features.mean(axis = 0)
    
    features = features - mean

    covariance = np.dot(features.T, features)

    #print("covariance = ", covariance )        
    #print(" features", features) 
    
    # To compute PCA  and keep only 64 dimensions
    eig_values, eig_vecs = np.linalg.eig(covariance)
    
    
    # To sort eig_values by increasing value
    perm = eig_values.argsort() 

    PCA = eig_vecs[:, perm[64:128]]
 
    
    features = np.matmul(features, PCA)
            
    print("final features = ", features.shape)     
    
    
    #To train kmeans model on the extracted features and return centers for each cluster:
    visualDictionary = KMeans(n_clusters=k,init='k-means++',tol=0.0001).fit(features)
    return visualDictionary, features



#To call getVLADVectorModel and store features in three different lists
for method in methods:
    if method == "SIFT":
        
        #An array to store computed visual dictionary using SIFT features
        visualDictionary_SIFT , VLAD_sift_f= (getVLADVectorModel(imageFeatures_SIFT, k, method))

    elif method == "Dense":
        
        #An array to store computed visual dictionary  using Dense SIFT featurs
        visualDictionary_Dense, VLAD_dense_f = (getVLADVectorModel(imageFeatures_Dense, k, method))
        
    

print("SIFT Visual Dictionary: ", visualDictionary_SIFT)
print("Dense Visual Dictionary: ", visualDictionary_Dense)
# Out:
# final features =  (3072, 64)
# final features =  (3072, 64)
# SIFT Visual Dictionary:  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=64, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)
# Dense Visual Dictionary:  KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=64, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
#Question(3)
#Step(4): To build a function that Compute Fisher Vector Aggregation of Images, from the given FV models

#Python function to compute FV aggregation
def getFisherVectorAggregation(features, gmm):
    
    
    features = np.atleast_2d(features)
    S = features.shape[0]

    # To get the posterior probabilities of the features
    pp = gmm.predict_proba(features)  

    # to get the sufficient statistics of descriptors.
    pp_sum = np.sum(pp, 0)[:, np.newaxis] / S
    ss1 = np.dot(pp.T, features) / S
    ss2 = np.dot(pp.T, features ** 2) / S

    # to get derivatives with respect to mixing weights, means and variances.
    d1 = pp_sum.squeeze() - gmm.weights_
    d2 = ss1 - pp_sum * gmm.means_
    d3 = (
        - ss2
        - pp_sum * gmm.means_ ** 2
        + pp_sum * gmm.covariances_
        + 2 * ss1 * gmm.means_)

    # Merge three derivatives into fisher vector.
    fv = np.hstack((d1, d2.flatten(), d3.flatten()))
    
    
    return fv


#To call getFisherVectorAggregation and store fv in a list
for method in methods:
    if method == "SIFT":
        
        #An array to store computed fv for SIFT features
        fv_SIFT = (getFisherVectorAggregation(sift_f, fv_GMM_SIFT))

    elif method == "Dense":
        
        #An array to store computed fv for Dense SIFT featurs
        fv_Dense = (getFisherVectorAggregation(dense_f, fv_GMM_Dense))
        
    #elif method =="HoG":
        
        #fv_GMM_HoG.append(getFisherVectorModel(imageFeatures_HoG, k))
        
#To print fv arrays shape
print("Sift FV shape: ", fv_SIFT.shape)
print("Dense FV shape: ", fv_Dense.shape)
# Out:
# Sift FV shape:  (266304,)
# Dense FV shape:  (266304,)

# %%
#Question(3)
#To build a function that Compute VLAD Aggregation of Images, from the given VLAD models

#Python function to compute vlad aggregation
def getVladAggregation(features, vlad_kmean):
    
    #to get important values from visual dictionary (vlad_kmean)
    
    #To test model on the same features we used before
    predicted_Labels = vlad_kmean.predict(features)
    
    #to get the list of clusters' centers from the model
    centers = vlad_kmean.cluster_centers_
    
    #To get labels and number of clusters
    labels=vlad_kmean.labels_
    k=vlad_kmean.n_clusters
   
    r,dimensions = features.shape
    vlad=np.zeros([k,dimensions])

    # for all the clusters k visual words dictionary
    for i in range(k):
        
        # To check if there is at least one descriptor in the cluster
        if np.sum(predicted_Labels==i)>0:
            # to add diferences to vector
            vlad[i]=np.sum(features[predicted_Labels==i,:]-centers[i],axis=0)
    

    vlad = vlad.flatten()
    
    # to perform power normalization on the vlad vector
    vlad = np.sign(vlad)*np.sqrt(np.abs(vlad))

    # to use L2 normalization with the vlad vector 
    vlad = vlad/np.sqrt(np.dot(vlad,vlad))
    
    return vlad


#To call getVladAggregation and store vlad 
for method in methods:
    if method == "SIFT":
        
        #An array to store computed vlad for SIFT features
        vlad_sift = (getVladAggregation(VLAD_sift_f, visualDictionary_SIFT))

    elif method == "Dense":
        
        #An array to store computed vlad for Dense SIFT featurs
        vlad_Dense = (getVladAggregation(VLAD_dense_f, visualDictionary_Dense))
        
    #elif method =="HoG":
        
        #fv_GMM_HoG.append(getFisherVectorModel(imageFeatures_HoG, k))
        
#To print Vlad arrays shape
print("Sift VLAD aggregation shape: ", vlad_sift.shape)
print("Dense VLAD aggregation shape: ", vlad_Dense.shape)
# Out:
# Sift VLAD aggregation shape:  (4096,)
# Dense VLAD aggregation shape:  (4096,)

# %%
#To show clustring result of the aggergation vector for vlad Dense sift 

range_n_clusters = [32, 64, 96]
data_vlad_dense = pd.DataFrame(vlad_Dense)

for n_clusters in range_n_clusters:
    
    
    clusterer = KMeans(n_clusters=n_clusters, init='k-means++', random_state=10, max_iter=300)
    cluster_labels = clusterer.fit_predict(data_vlad_dense)

    silhouette_avg = silhouette_score(data_vlad_dense, cluster_labels, metric='euclidean')
    print("For number of clusters =", n_clusters,
          "The average silhouette score is :", silhouette_avg)
# Out:
# For number of clusters = 32 The average silhouette score is : 0.5278013797816292
# For number of clusters = 64 The average silhouette score is : 0.5257711615169174
# For number of clusters = 96 The average silhouette score is : 0.5346599472287581

# %%
#To show clustring result of the aggergation vector for vlad sift 
range_n_clusters = [32, 64, 96]
data_vlad_sift = pd.DataFrame(vlad_sift)

for n_clusters in range_n_clusters:
    
    
    clusterer = KMeans(n_clusters=n_clusters, init='k-means++', random_state=10, max_iter=300)
    cluster_labels = clusterer.fit_predict(data_vlad_sift)

    silhouette_avg = silhouette_score(data_vlad_sift, cluster_labels, metric='euclidean')
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)
# Out:
# For n_clusters = 32 The average silhouette_score is : 0.5299883265648535
# For n_clusters = 64 The average silhouette_score is : 0.5326858861503089
# For n_clusters = 96 The average silhouette_score is : 0.5407097210403554

# %%
#To show clustring result of the aggergation vector for fisher vector sift 
range_n_clusters = [32, 64, 96]
data_fv_sift = pd.DataFrame(fv_SIFT)

for n_clusters in range_n_clusters:
    
    
    clusterer = KMeans(n_clusters=n_clusters, init='k-means++', random_state=10, max_iter=300)
    cluster_labels = clusterer.fit_predict(data_fv_sift.head(200))

    silhouette_avg = silhouette_score(data_fv_sift.head(200), cluster_labels, metric='euclidean')
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)
# Out:
# /home/mahzari/anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:969: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (32). Possibly due to duplicate points in X.
#   return_n_iter=True)
# For n_clusters = 32 The average silhouette_score is : 0.955
# /home/mahzari/anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:969: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (64). Possibly due to duplicate points in X.
#   return_n_iter=True)
# For n_clusters = 64 The average silhouette_score is : 0.955
# For n_clusters = 96 The average silhouette_score is : 0.955
# /home/mahzari/anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:969: ConvergenceWarning: Number of distinct clusters (19) found smaller than n_clusters (96). Possibly due to duplicate points in X.
#   return_n_iter=True)

# %%
#To show clustring result of the aggergation vector for fisher vector Dense Sift 
range_n_clusters = [32, 64, 96]
data_fv_Dense_sift= pd.DataFrame(fv_Dense)

for n_clusters in range_n_clusters:
    
    
    clusterer = KMeans(n_clusters=n_clusters, init='k-means++', random_state=10, max_iter=300)
    cluster_labels = clusterer.fit_predict(data_fv_Dense_sift.head(200))

    silhouette_avg = silhouette_score(data_fv_Dense_sift.head(200), cluster_labels, metric='euclidean')
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)
# Out:
# /home/mahzari/anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:969: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (32). Possibly due to duplicate points in X.
#   return_n_iter=True)
# For n_clusters = 32 The average silhouette_score is : 0.985
# /home/mahzari/anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:969: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (64). Possibly due to duplicate points in X.
#   return_n_iter=True)
# For n_clusters = 64 The average silhouette_score is : 0.985
# For n_clusters = 96 The average silhouette_score is : 0.985
# /home/mahzari/anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:969: ConvergenceWarning: Number of distinct clusters (18) found smaller than n_clusters (96). Possibly due to duplicate points in X.
#   return_n_iter=True)

# %%
#To visualize Dense sift VLAD Distance
data = pd.DataFrame(vlad_Dense)
distance_data = data.head(500)


d = euclidean_distances(distance_data,distance_data)

fig, ax = plt.subplots()
ax.set_title('Dense sift VLAD Distance')
ax.imshow(d)

# %%
#To visualize Dense sift FV Distance
data = pd.DataFrame(fv_Dense)
distance_data = data.head(500)


d = euclidean_distances(distance_data,distance_data)

fig, ax = plt.subplots()
ax.set_title('Dense sift FV Distance')
ax.imshow(d)

# %%
#To visualize sift VLAD Distance
data = pd.DataFrame(vlad_sift)
distance_data = data.head(500)


d = euclidean_distances(distance_data,distance_data)

fig, ax = plt.subplots()
ax.set_title('SIFT VLAD Distance')
ax.imshow(d)

# %%
#To visualize sift FV Distance
data = pd.DataFrame(fv_SIFT)
distance_data = data.head(500)


d = euclidean_distances(distance_data,distance_data)

fig, ax = plt.subplots()
ax.set_title('SIFT FV Distance')
ax.imshow(d)

# %%
#To visualize sift Distance
data = pd.DataFrame(sift_f)
distance_data = data.head(500)


d = euclidean_distances(distance_data,distance_data)

fig, ax = plt.subplots()
ax.set_title('SIFT  Distance')
ax.imshow(d)

# %%
#To visualize Dense Sift Distance
data = pd.DataFrame(dense_f)
distance_data = data.head(500)


d = euclidean_distances(distance_data,distance_data)

fig, ax = plt.subplots()
ax.set_title('Dense Sift Distance')
ax.imshow(d)

# %%
#To visualize Ground Truth Dense Sift features distance
data = pd.DataFrame(imageFeatures_Dense)
distance_data = data.head(500)


d = euclidean_distances(distance_data,distance_data)

fig, ax = plt.subplots()
ax.set_title('Ground Truth Dense Sift features distance')
ax.imshow(d)

# %%
#To visualize Ground Truth Sift features distance
data = pd.DataFrame(imageFeatures_SIFT)
distance_data = data.head(500)


d = euclidean_distances(distance_data,distance_data)

fig, ax = plt.subplots()
ax.set_title('Ground Truth Sift features distance')
ax.imshow(d)
